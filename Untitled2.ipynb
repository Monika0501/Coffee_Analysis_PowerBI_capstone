# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika0501/Coffee_Analysis_PowerBI_capstone/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.What is a variable in Python? Write one example.
#Variable is like a container we can store a value in it i., name="monika" therfore name is variable

# %%
#2.Which of the following variable names are valid and which are invalid?

age -valid
2name-invalid
_total-valid
first-name-invalid
salary123-valid

# %%
#3.Write a Python statement to store:

#your name in a variable
#your age in a variable

Name="monika"
Age=21
print(Name)
print(Age)
print(type(Name))
print(type(Age))
# Out:
# monika
# 21
# <class 'str'>
# <class 'int'>

# %%
#4.What will be the output of this code?

x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %%
#5.Identify the data type of each variable:
a=25
b=3.5
c="Python"
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#6.What is the difference between:

x = 5 #x value is integer
x = "5" #x value is string Though they look similar, they behave differently in operations.

# %%
#7.What will be the output?

a, b, c = 1, 2, 3
print(a + b * c)
# Out:
# 7

# %%
8#What error will this code give (if any)?

a = 10
#print(A)
#name A is not defind

# %%
#10.Can you change the value of a variable after assigning it?
#Write a small example to explain.

# %%
#Write a Python program to swap the values of two variables.

# %%
#Write a program to store your city and pincode in variables.
city="Hyd"
pincode=500026

print(city)
print(pincode)

#What are valid variable names: my_name, my name, _age, @price?
my_name ="monika"
_age=25
print(my_name)
print(_age)

#What will be the output?
x = 1
y = 2
z = x + y
print(z)

#Write a program to change the value of a variable.

my_name="monika"
monika="moni"
print(my_name)

#What is the difference between a = 10 and a = "10"?
a=10 # a is a variable 10 is a value type is int
a="10" # a is a variable "10" is a value,type is string
# Out:
# Hyd
# 500026
# monika
# 25
# 3
# monika

# %%
status = "Started"
print("Step 1:", status)

status = "In Progress"
print("Step 2:", status)

status = "Almost Done"
print("Step 3:", status)

status = "Completed"
print("Final:", status)
# Out:
# Step 1: Started
# Step 2: In Progress
# Step 3: Almost Done
# Final: Completed

# %%
#Implicit type casting
a=10
b=2.7

c=a+b
print(c)
print(type(c))
# Out:
# 12.7
# <class 'float'>

# %%
#explicit type casting
x="10"
y=int(x)
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
x="10"
y=float(y)
print(y)
print(type(y))
# Out:
# 10.0
# <class 'float'>

# %%
x="10"
y=str(x)
print(y)
print(type(y))
# Out:
# 10
# <class 'str'>

# %%
a=input("Enter first number")
b=input("Enter second number")
print(a+b)
# Out:
# Enter first number10
# Enter second number20
# 1020

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a+b)
# Out:
# Enter first number10
# Enter second number20
# 30

# %%
#Write a program to take your city name and print it.
city=input("Enter your city name")
print(city)
# Out:
# Enter your city nameHyderabad
# Hyderabad

# %%
#Take two numbers using input() and print their product.
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
product=a*b
print("product=",product)
# Out:
# Enter first number: 10
# Enter second number: 20
# product= 200

# %%
name="monika"
age=21
print(f"my name is {name} and my age is{age}")
# Out:
# my name is monika and my age is21

# %%
#F'string with input
city=input("enter your city:")
pincode=input("Enter pincode: ")

print(f"I live in {city} and my pincode is {pincode}")
# Out:
# enter your city:Hyderabad
# Enter pincode: 500026
# I live in Hyderabad and my pincode is 500026

# %%
#f"string with calculations
a=10
b=5
print(f"sum={a+b}")
print(f"product={a*b}")
# Out:
# sum=15
# product=50

# %%
#Use f‑string to print your name and age
name="monika"
age=25

print(f"my name is {name} and age is {age}")
# Out:
# my name is monika and age is 25

# %%
#Take two numbers using input() and print their sum using f‑string

a= int(input("Enter first number"))
b= int(input("Enter second number"))

print(f"sum={a+b}")
# Out:
# Enter first number10
# Enter second number10
# sum=20

# %%
#Print the square of a number using f‑string
num=int(input("Enter a number"))
print(f"square of {num} is {num*num}")
# Out:
# Enter a number5
# square of 5 is 25

# %%
a="10"
b=5
print(a+str(b))
# Out:
# 105
